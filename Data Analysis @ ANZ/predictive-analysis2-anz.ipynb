# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts
from sklearn.pipeline import make_pipeline


sns.set()

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.7/site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.7/site-packages (from openpyxl) (1.1.0)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
df=pd.read_excel('../input/anz-transactions-dataset/ANZ synthesised transaction dataset.xlsx', engine="openpyxl")
df.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# 0            NaN      Diana  ...   26         Ashmore            QLD
# 1            NaN      Diana  ...   26          Sydney            NSW
# 2            NaN    Michael  ...   38          Sydney            NSW
# 3            NaN     Rhonda  ...   40         Buderim            QLD
# 4            NaN      Diana  ...   26   Mermaid Beach            QLD
#
#                      extraction amount                    transaction_id  \
# 0  2018-08-01T01:01:15.000+0000  16.25  a623070bfead4541a6b0fff8a09e706c
# 1  2018-08-01T01:13:45.000+0000  14.19  13270a2a902145da9db4c951e04b51b9
# 2  2018-08-01T01:26:15.000+0000   6.42  feb79e7ecd7048a5a36ec889d1a94270
# 3  2018-08-01T01:38:45.000+0000  40.90  2698170da3704fd981b15e64a006079e
# 4  2018-08-01T01:51:15.000+0000   3.25  329adf79878c4cf0aeb4188b4691c266
#
#      country     customer_id merchant_long_lat movement
# 0  Australia  CUS-2487424745     153.38 -27.99    debit
# 1  Australia  CUS-2487424745     151.21 -33.87    debit
# 2  Australia  CUS-2142601169     151.21 -33.87    debit
# 3  Australia  CUS-1614226872     153.05 -26.68    debit
# 4  Australia  CUS-2487424745     153.44 -28.06    debit
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (12043, 23)

# %%
df.columns
# Out:
# Index(['status', 'card_present_flag', 'bpay_biller_code', 'account',
#        'currency', 'long_lat', 'txn_description', 'merchant_id',
#        'merchant_code', 'first_name', 'balance', 'date', 'gender', 'age',
#        'merchant_suburb', 'merchant_state', 'extraction', 'amount',
#        'transaction_id', 'country', 'customer_id', 'merchant_long_lat',
#        'movement'],
#       dtype='object')

# %%
df.describe()
# Out:
#        card_present_flag  merchant_code        balance           age  \
# count        7717.000000          883.0   12043.000000  12043.000000
# mean            0.802644            0.0   14704.195553     30.582330
# std             0.398029            0.0   31503.722652     10.046343
# min             0.000000            0.0       0.240000     18.000000
# 25%             1.000000            0.0    3158.585000     22.000000
# 50%             1.000000            0.0    6432.010000     28.000000
# 75%             1.000000            0.0   12465.945000     38.000000
# max             1.000000            0.0  267128.520000     78.000000
#
#              amount
# count  12043.000000
# mean     187.933588
# std      592.599934
# min        0.100000
# 25%       16.000000
# 50%       29.000000
# 75%       53.655000
# max     8835.980000

# %%
df.customer_id.duplicated().sum()
# Out:
# 11943

# %% [markdown]
# ### there are many duplicate customer id's. so we gonna create a new data frame with unique id

# %%
salaries_df=pd.DataFrame({"Customer_id":df.customer_id.unique()})
salaries_df.head()
# Out:
#       Customer_id
# 0  CUS-2487424745
# 1  CUS-2142601169
# 2  CUS-1614226872
# 3  CUS-2688605418
# 4  CUS-4123612273

# %% [markdown]
# #### Now we'll try to calculate the salary for the each of the customers

# %%
df_freq=[]
df_amount=[]

for customer in range(len(salaries_df)):
    salary=df.loc[(df.customer_id==salaries_df.Customer_id[customer]) & (df.txn_description=='PAY/SALARY'),['date','amount']].groupby('date',as_index=False).sum()
    count=len(salary)
    if(count==0):
        df_freq.append(np.nan)
        df_amount.append(np.nan)
    else:
        dbp=[]
        for date in range(len(salary)-1):
            dbp.append((salary.date[date+1]- salary.date[date]).days)
        df_freq.append(max(dbp))
        df_amount.append(sts.mode(salary.amount))

salaries_df['sal_freq']=df_freq
salaries_df['amount']=df_amount
salaries_df['annual_salary']=salaries_df.amount/salaries_df.sal_freq*365

# %%
salaries_df.head()
# Out:
#       Customer_id  sal_freq   amount  annual_salary
# 0  CUS-2487424745         7  1013.67   52855.650000
# 1  CUS-2142601169         7  1002.13   52253.921429
# 2  CUS-1614226872         7   892.09   46516.121429
# 3  CUS-2688605418        14  2320.30   60493.535714
# 4  CUS-4123612273         7  1068.04   55690.657143

# %% [markdown]
# ### From the above dataset we can also derive various information like weekly transactions,max_amount transaction,average transactions,median_balances etc

# %%
unique_id=salaries_df.Customer_id.unique()
unique_id[:10]
# Out:
# array(['CUS-2487424745', 'CUS-2142601169', 'CUS-1614226872',
#        'CUS-2688605418', 'CUS-4123612273', 'CUS-3026014945',
#        'CUS-2031327464', 'CUS-2317998716', 'CUS-1462656821',
#        'CUS-3142625864'], dtype=object)

# %% [markdown]
# ### Maximum Transactions

# %%
max_tran=[]
for i in unique_id:
    p=df.loc[df.customer_id==i,"amount"]
    max_tran.append(max(p))

# %%
max_tran[:5]
# Out:
# [1452.21, 2349.55, 892.09, 2320.3, 1068.04]

# %% [markdown]
# ### Weekly Transactions

# %%
week_tran=[]

for i in unique_id:
    p=df.loc[df.customer_id==i,"date"]
    week_tran.append(len(p)/p.nunique()*7)

# %%
print(p.nunique())
# Out:
# 60

# %% [markdown]
# #### Avergae Transactions

# %%
avg_tran=[]

for i in unique_id:
    p=df.loc[df.customer_id==i,"amount"]
    avg_tran.append(np.mean(p))

# %% [markdown]
# ### Mode Transactions

# %%
mode_tran=[]

for i in unique_id:
    p=df.loc[df.customer_id==i,"amount"]
    mode_tran.append(p.median())

# %% [markdown]
# #### Age

# %%
age=[]

for i in unique_id:
    p=df.loc[df.customer_id==i,"age"]
    age.append(sts.mode(p))

# %% [markdown]
# ### Gender

# %%
gender=[]

for i in unique_id:
    p=df.loc[df.customer_id==i,"gender"]
    gender.append(sts.mode(p))

# %% [markdown]
# ### Merging feature into a single dataframe

# %%
feature_df=pd.DataFrame({
    
    'customer_id':unique_id,
    'gender':gender,
    'age':age,
    'mode_transaction':mode_tran,
    'average_transaction':avg_tran,
    'weekly_transaction':week_tran  
    
})

# %%
feature_df.head()
# Out:
#       customer_id gender  age  mode_transaction  average_transaction  \
# 0  CUS-2487424745      F   26             11.28            45.348772
# 1  CUS-2142601169      M   38             15.97            78.206106
# 2  CUS-1614226872      F   40             25.38            74.465019
# 3  CUS-2688605418      M   20             24.00           159.304186
# 4  CUS-4123612273      F   43             29.46           166.508358
#
#    weekly_transaction
# 0           47.600000
# 1           28.662162
# 2           23.855263
# 3           14.333333
# 4           21.318182

# %% [markdown]
# ### Merging the Annual_salary and the feature dataframe

# %%
data=pd.concat([feature_df,salaries_df.annual_salary],axis=1)

# %%
data.drop('customer_id',axis=1,inplace=True)

# %%
data.head()
# Out:
#   gender  age  mode_transaction  average_transaction  weekly_transaction  \
# 0      F   26             11.28            45.348772           47.600000
# 1      M   38             15.97            78.206106           28.662162
# 2      F   40             25.38            74.465019           23.855263
# 3      M   20             24.00           159.304186           14.333333
# 4      F   43             29.46           166.508358           21.318182
#
#    annual_salary
# 0   52855.650000
# 1   52253.921429
# 2   46516.121429
# 3   60493.535714
# 4   55690.657143

# %%
df_final=pd.get_dummies(data)
df_final.head()
# Out:
#    age  mode_transaction  average_transaction  weekly_transaction  \
# 0   26             11.28            45.348772           47.600000
# 1   38             15.97            78.206106           28.662162
# 2   40             25.38            74.465019           23.855263
# 3   20             24.00           159.304186           14.333333
# 4   43             29.46           166.508358           21.318182
#
#    annual_salary  gender_F  gender_M
# 0   52855.650000         1         0
# 1   52253.921429         0         1
# 2   46516.121429         1         0
# 3   60493.535714         0         1
# 4   55690.657143         1         0

# %% [markdown]
# #### Performing Standarization

# %%
from sklearn.preprocessing import StandardScaler
cols=['age','mode_transaction','average_transaction','weekly_transaction','annual_salary']

# %%
scaler=StandardScaler()

# %%
# df_final[cols]=scaler.fit_transform(df_final[cols])

# %%
df_final.head()
# Out:
#    age  mode_transaction  average_transaction  weekly_transaction  \
# 0   26             11.28            45.348772           47.600000
# 1   38             15.97            78.206106           28.662162
# 2   40             25.38            74.465019           23.855263
# 3   20             24.00           159.304186           14.333333
# 4   43             29.46           166.508358           21.318182
#
#    annual_salary  gender_F  gender_M
# 0   52855.650000         1         0
# 1   52253.921429         0         1
# 2   46516.121429         1         0
# 3   60493.535714         0         1
# 4   55690.657143         1         0

# %%
target=df_final['annual_salary']
input=df_final.drop(['annual_salary'],axis=1)

# %%
input
# Out:
#     age  mode_transaction  average_transaction  weekly_transaction  gender_F  \
# 0    26             11.28            45.348772           47.600000         1
# 1    38             15.97            78.206106           28.662162         0
# 2    40             25.38            74.465019           23.855263         1
# 3    20             24.00           159.304186           14.333333         0
# 4    43             29.46           166.508358           21.318182         1
# ..  ...               ...                  ...                 ...       ...
# 95   40             38.83           291.293333           14.000000         1
# 96   42             78.15           448.658413           11.307692         0
# 97   42             45.00           355.400250            8.484848         0
# 98   34             46.00           245.600169           15.296296         1
# 99   29             39.00           274.523358           15.633333         0
#
#     gender_M
# 0          0
# 1          1
# 2          0
# 3          1
# 4          0
# ..       ...
# 95         0
# 96         1
# 97         1
# 98         0
# 99         1
#
# [100 rows x 6 columns]

# %% [markdown]
# #### Train and Test split using sklearn

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input,target,test_size=0.2)

# %% [markdown]
# ### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.5200929244831389

# %% [markdown]
# ### RMSE

# %%
from sklearn.metrics import mean_squared_error as MSE

pred = lr.predict(x_test)
  
# RMSE Computation
rmse = np.sqrt(MSE(y_test, pred))
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  18634.216612

# %% [markdown]
# ### R2 Score

# %%
from sklearn.metrics import r2_score
k=r2_score(y_test,pred)
k
# Out:
# 0.5200929244831389
